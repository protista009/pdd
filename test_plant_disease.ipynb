# %%
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
import matplotlib.pyplot as plt

# %%
model= tf.keras .models.load_model('train_model.keras')
# Out:
# E:\anaconda\Lib\site-packages\keras\src\saving\saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 26 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
model.summary
# Out:
# <bound method Model.summary of <Sequential name=sequential, built=True>>

# %% [raw]
# Visualizing single image pf test set

# %%
class_name = ['healthy', 'unhealthy']

# %%
image_path="test/testimg/leaf.png"

img=cv2.imread(image_path)

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Display the image
plt.figure()
plt.imshow(img)
plt.title("image")
plt.xticks([])  # Remove x-axis ticks
plt.yticks([])  # Remove y-axis ticks
plt.show()

# %%
## Testing model

# %%
image =tf.keras.preprocessing.image.load_img(image_path,target_size=(128,128))
input_arr=tf.keras.preprocessing.image.img_to_array(image)
input_arr=np.array([input_arr]) #convert single image to batch
print(input_arr.shape)
# Out:
# (1, 128, 128, 3)

# %%
prediction=model.predict(input_arr)
prediction,prediction.shape
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# (array([[2.71238722e-02, 2.55052443e-03, 1.84752606e-02, 1.09043114e-01,
#          2.92081200e-02, 2.50773365e-03, 4.62907143e-02, 4.18675249e-04,
#          4.25646501e-03, 1.56445522e-02, 1.25043420e-03, 5.77387691e-04,
#          3.52136063e-04, 1.27709028e-03, 1.94939226e-02, 3.64853650e-01,
#          8.15959834e-03, 7.53406712e-05, 3.02817440e-03, 3.57102859e-03,
#          4.20869933e-03, 7.14055868e-03, 3.33188064e-02, 6.86820410e-03,
#          1.49943249e-03, 6.84548542e-03, 7.94492811e-02, 7.84969016e-04,
#          1.61195658e-02, 5.44801995e-04, 4.15910315e-03, 4.15854016e-03,
#          3.12665524e-03, 4.12351526e-02, 2.71674152e-02, 9.06378925e-02,
#          3.86574934e-03, 1.07118487e-02]], dtype=float32),
#  (1, 38))

# %%
result_index = np.argmax(prediction)
result_index
# Out:
# 15

# %%
print(f"🔍 Prediction shape: {prediction.shape}, Prediction values: {prediction}")
# Out:
# 🔍 Prediction shape: (1, 38), Prediction values: [[2.71238722e-02 2.55052443e-03 1.84752606e-02 1.09043114e-01
#   2.92081200e-02 2.50773365e-03 4.62907143e-02 4.18675249e-04
#   4.25646501e-03 1.56445522e-02 1.25043420e-03 5.77387691e-04
#   3.52136063e-04 1.27709028e-03 1.94939226e-02 3.64853650e-01
#   8.15959834e-03 7.53406712e-05 3.02817440e-03 3.57102859e-03
#   4.20869933e-03 7.14055868e-03 3.33188064e-02 6.86820410e-03
#   1.49943249e-03 6.84548542e-03 7.94492811e-02 7.84969016e-04
#   1.61195658e-02 5.44801995e-04 4.15910315e-03 4.15854016e-03
#   3.12665524e-03 4.12351526e-02 2.71674152e-02 9.06378925e-02
#   3.86574934e-03 1.07118487e-02]]

# %%
model_prediction = class_name[result_index]
plt.figure()
plt.imshow(img)
plt.title(f"disease : {model_prediction}")
plt.xticks([])  # Remove x-axis ticks
plt.yticks([])  # Remove y-axis ticks
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 model_prediction = class_name[result_index]
#       2 plt.figure()
#       3 plt.imshow(img)
#
# IndexError: list index out of range
